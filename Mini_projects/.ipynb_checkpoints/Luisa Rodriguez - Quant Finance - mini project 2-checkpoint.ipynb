# %% [markdown]
# # Mini Project 2
#
# **2025 Introduction to Quantiative Methods in Finance**
#
# **The Erdös Institute**
#
#
# ###  Hypothesis Testing of Standard Assumptions Theoretical Financial Mathematics
#
# In the theory of mathematical finance, it is common to assume the log returns of a stock/index are normally distributed.
#
#
# Investigate if the log returns of stocks or indexes of your choosing are normally distributed. Some suggestions for exploration include:
#
#     1) Test if there are period of times when the log-returns of a stock/index have evidence of normal distribution.
#
#     2) Test if removing extremal return data creates a distribution with evidence of being normal.
#
#     3) Create a personalized portfolio of stocks with historical log return data that is normally distributed.
#
#     4) Test if the portfolio you created in the first mini-project has significant periods of time with evidence of normally distributed log returns.
#
#     5) Gather x-number of historical stock data and just perform a normality test on their log return data to see if any of the stocks exhibit evidence of log returns that are normally distributed.

# %%
#Import Packages
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy.optimize import minimize
import datetime as dt
sns.set_style('darkgrid')
import yfinance as yf
import numpy.random as npr
import math
import seaborn as sns
npr.seed(42)
import scipy.stats as stats
sns.set_style('darkgrid')
import random

image_save_dpi = 1200
image_format = "pdf"

# %%
def ranges(nums):
    nums = sorted(set(nums))
    gaps = [[s, e] for s, e in zip(nums, nums[1:]) if s+1 < e]
    edges = iter(nums[:1] + sum(gaps, []) + nums[-1:])
    return np.array(list(zip(edges, edges)))

def mergeOverlap(arr):
    #function taken from: https://www.geeksforgeeks.org/dsa/merging-intervals/
    n = len(arr)

    arr.sort()
    res = []

    # Checking for all possible overlaps
    for i in range(n):
        start = arr[i][0]
        end = arr[i][1]

        # Skipping already merged intervals
        if res and res[-1][1] >= end:
            continue

        # Find the end of the merged range
        for j in range(i + 1, n):
            if arr[j][0] <= end:
                end = max(end, arr[j][1])
        res.append([start, end])
    
    return res

def normal_subintervals(log_daily_returns, 
                        days_samples,
                        size_days_samples, 
                        len_interval_samples, 
                        size_interval_samples, 
                        min_len  ):
    ndays = len(log_daily_returns)

    li = size_interval_samples*ndays #(ndays - min_len)*ndays 
    intervals = np.zeros((li, 2))
    p_values = np.zeros(li)
    c = 0

    for n in len_interval_samples:
        for i in days_samples:
            if i< (len(log_daily_returns)-(n-1)) :
                intervals[c,:] = [i, (i+n)]
                partition_log_daily_returns = log_daily_returns[range(i, (i+n))]
                p_values[c] = stats.normaltest(partition_log_daily_returns)[1]
                c = c+1
    candidate_intervals = intervals[p_values>0.05,:]
    candidate_intervals = candidate_intervals.tolist()
    normal_intervals = np.array(mergeOverlap(candidate_intervals))
    candidate_intervals = np.array(candidate_intervals)
    if np.shape(candidate_intervals)[0]>1:
        #print("siii")
        candidate_intervals = candidate_intervals[candidate_intervals[:, 0].argsort()]
        candidate_intervals_OK = candidate_intervals

        i_1 = np.zeros(( (np.shape(candidate_intervals_OK)[0] )*(np.shape(candidate_intervals_OK)[0] )  , 3),dtype=int )
        c=0
        for i in range(np.shape(candidate_intervals_OK)[0]):
            for j in range(np.shape(candidate_intervals_OK)[0]):
                if j>i:
                    i_1[c,0] = i
                    i_1[c,1] = j
                    compare_sub_1 = candidate_intervals_OK[i, :]
                    compare_sub_2 = candidate_intervals_OK[j, :]
                    if compare_sub_1[0]>= compare_sub_2[0] and compare_sub_1[1] <= compare_sub_2[1]:
                        # print(compare_sub_1, compare_sub_2, "overlap")    
                        i_1[c,2] = 1
                c = c+1

        candidate_intervals_OK = np.delete(candidate_intervals_OK, (i_1[i_1[:,2]>0, 0]) , axis=0)
        candidate_intervals_OK = candidate_intervals_OK[candidate_intervals_OK[:,0].argsort()].astype(int)
        return candidate_intervals_OK
    else:
        return np.zeros((1,2))

# %% [markdown]
# ## Solution

# %% [markdown]
# For the data exploration for the items 1, and 2, we are going to base the analyses on the NASDAQ composite index for a ten year period.

# %% [markdown]
# ## 1, 2) Test if there are period of times when the log-returns of a stock/index have evidence of normal distribution.

# %%
names_companies = ['^IXIC']
tickers = ['^IXIC']

end_date = '2025-06-25'
#start_date = dt.datetime.today()-dt.timedelta(days = 10*365)
start_date = pd.to_datetime(end_date) - dt.timedelta(days = 10*365)
#end_date = dt.datetime.today()
NASDAQ_index = yf.download(tickers, start=start_date, end=end_date)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
#Plot Closing Price stock data
image_name = "source_reports/images/figure_1_project_2"

NASDAQ_index['Close'][tickers].plot(figsize = (12,8))
plt.title(f'Stock data of {tickers}', size = 18)
plt.ylabel('Price (USD)')
plt.savefig(image_name, format = image_format, dpi = image_save_dpi)

plt.show()

# %%
daily_returns_NASDAQ_index = NASDAQ_index['Close']/NASDAQ_index['Close'].shift(1)
log_daily_returns_NASDAQ_index = np.log(daily_returns_NASDAQ_index)
log_daily_returns_NASDAQ_index = log_daily_returns_NASDAQ_index.dropna()

image_name = "source_reports/images/figure_2_project_2"

log_daily_returns_NASDAQ_index[tickers].plot(figsize = (12,8))
plt.title(f'Log daily Returns', size = 25)
plt.ylabel('')
#plt.savefig(image_name, format = image_format, dpi = image_save_dpi)

plt.show()

sns.violinplot( data = log_daily_returns_NASDAQ_index*252, order=tickers)
plt.title('Violinplot log daily returns in anualized form ^IXIC', size=16)

(log_daily_returns_NASDAQ_index*252).hist(figsize=(5.6,3), bins=50)
plt.title('Histogram log daily returns in anualized form ^IXIC', size=16)
plt.show()

# %% [markdown]
# We going to explore within this time period for time intervals in which this index is normally distributed. For this, we are going to generate random partitions over the ten years period, calculate the p-values for each of those partitions, and cave the candidate set of partitions. After this, the algorithm merge the candidate subintervals. This is, for given intervals $[a, b], [c, d]$ if $[c,d] \subset [a,b]$  the algorithm will store the interval $[a, b]$ and remove $[c, d]$.

# %%
min_len_NASDAQ =  int(np.floor(252/3)) # 4 months
ndays_NASDAQ = len(log_daily_returns_NASDAQ_index)

size_interval_samples_NASDAQ = 50 
len_interval_samples_NASDAQ = np.sort(random.sample(range(min_len_NASDAQ, ndays_NASDAQ), size_interval_samples_NASDAQ)) 

size_days_samples_NASDAQ = 50
days_samples_NASDAQ = np.sort(random.sample(range(0, ndays_NASDAQ), size_days_samples_NASDAQ))

# %%
log_daily_returns_NASDAQ_index_1= np.array(log_daily_returns_NASDAQ_index.iloc[:,0])

# %%
normal_candidate_intervals_NASDAQ = normal_subintervals(log_daily_returns= log_daily_returns_NASDAQ_index_1, 
                        days_samples=days_samples_NASDAQ,
                        size_days_samples=size_days_samples_NASDAQ, 
                        len_interval_samples =len_interval_samples_NASDAQ, 
                        size_interval_samples=size_interval_samples_NASDAQ, 
                        min_len=min_len_NASDAQ)

# %% [markdown]
# Returning p-values for all the normal subintervals produced by the sample:

# %%
for j in range(np.shape(normal_candidate_intervals_NASDAQ)[0]):
    historical_NASDAQ = log_daily_returns_NASDAQ_index_1[range(int(normal_candidate_intervals_NASDAQ[j,0]), int(normal_candidate_intervals_NASDAQ[j,1]) )]

    p_value = stats.normaltest(historical_NASDAQ)[1]

    n = int(normal_candidate_intervals_NASDAQ[j,1]) - int(normal_candidate_intervals_NASDAQ[j,0])

    print('-----------------------')
    print('From: ', log_daily_returns_NASDAQ_index.index.tolist()[int(normal_candidate_intervals_NASDAQ[j,0]) ] , ' To: ', log_daily_returns_NASDAQ_index.index.tolist()[int(normal_candidate_intervals_NASDAQ[j,1]) ])
    print('Number of days', { n} )
    print(f"Log return distribution: p-value = {p_value:.4f}")
    print("→ No statistically significant evidence against normality.")
# Out:
# -----------------------
# From:  2015-12-08 00:00:00  To:  2016-05-31 00:00:00
# Number of days {119}
# Log return distribution: p-value = 0.1777
# → No statistically significant evidence against normality.
# -----------------------
# From:  2016-10-06 00:00:00  To:  2017-03-29 00:00:00
# Number of days {119}
# Log return distribution: p-value = 0.0707
# → No statistically significant evidence against normality.
# -----------------------
# From:  2016-10-17 00:00:00  To:  2017-04-07 00:00:00
# Number of days {119}
# Log return distribution: p-value = 0.0549
# → No statistically significant evidence against normality.
# -----------------------
# From:  2018-09-21 00:00:00  To:  2019-03-13 00:00:00
# Number of days {117}
# Log return distribution: p-value = 0.0532
# → No statistically significant evidence against normality.
# -----------------------
# From:  2018-10-03 00:00:00  To:  2019-03-27 00:00:00
# Number of days {119}
# Log return distribution: p-value = 0.0711
# → No statistically significant evidence against normality.
# -----------------------
# From:  2018-10-04 00:00:00  To:  2019-03-28 00:00:00
# Number of days {119}
# Log return distribution: p-value = 0.0731
# → No statistically significant evidence against normality.
# -----------------------
# From:  2020-09-09 00:00:00  To:  2022-04-21 00:00:00
# Number of days {407}
# Log return distribution: p-value = 0.1056
# → No statistically significant evidence against normality.
# -----------------------
# From:  2020-09-09 00:00:00  To:  2021-04-26 00:00:00
# Number of days {157}
# Log return distribution: p-value = 0.1914
# → No statistically significant evidence against normality.
# -----------------------
# From:  2020-09-09 00:00:00  To:  2021-03-02 00:00:00
# Number of days {119}
# Log return distribution: p-value = 0.1232
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-09-09 00:00:00  To:  2023-06-12 00:00:00
# Number of days {441}
# Log return distribution: p-value = 0.0802
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-09-30 00:00:00  To:  2023-07-05 00:00:00
# Number of days {441}
# Log return distribution: p-value = 0.0709
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-09-30 00:00:00  To:  2023-05-15 00:00:00
# Number of days {407}
# Log return distribution: p-value = 0.1800
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-09-30 00:00:00  To:  2022-12-14 00:00:00
# Number of days {304}
# Log return distribution: p-value = 0.4649
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-09-30 00:00:00  To:  2022-12-07 00:00:00
# Number of days {299}
# Log return distribution: p-value = 0.5177
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-09-30 00:00:00  To:  2022-03-18 00:00:00
# Number of days {117}
# Log return distribution: p-value = 0.9296
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-19 00:00:00  To:  2023-07-24 00:00:00
# Number of days {441}
# Log return distribution: p-value = 0.0680
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-19 00:00:00  To:  2022-12-27 00:00:00
# Number of days {299}
# Log return distribution: p-value = 0.5927
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-20 00:00:00  To:  2023-07-25 00:00:00
# Number of days {441}
# Log return distribution: p-value = 0.0677
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-11-22 00:00:00  To:  2022-05-13 00:00:00
# Number of days {119}
# Log return distribution: p-value = 0.2105
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-11-22 00:00:00  To:  2023-02-01 00:00:00
# Number of days {299}
# Log return distribution: p-value = 0.8700
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-11-22 00:00:00  To:  2023-07-10 00:00:00
# Number of days {407}
# Log return distribution: p-value = 0.2367
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-11-22 00:00:00  To:  2023-08-25 00:00:00
# Number of days {441}
# Log return distribution: p-value = 0.1164
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-13 00:00:00  To:  2023-08-29 00:00:00
# Number of days {407}
# Log return distribution: p-value = 0.1024
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-02-10 00:00:00  To:  2023-05-26 00:00:00
# Number of days {324}
# Log return distribution: p-value = 0.3191
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-02-10 00:00:00  To:  2023-04-28 00:00:00
# Number of days {304}
# Log return distribution: p-value = 0.5038
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-04-14 00:00:00  To:  2022-11-29 00:00:00
# Number of days {157}
# Log return distribution: p-value = 0.7012
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-04-28 00:00:00  To:  2022-12-12 00:00:00
# Number of days {157}
# Log return distribution: p-value = 0.5706
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-05-31 00:00:00  To:  2023-01-13 00:00:00
# Number of days {157}
# Log return distribution: p-value = 0.1194
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-01-19 00:00:00  To:  2023-09-05 00:00:00
# Number of days {157}
# Log return distribution: p-value = 0.5473
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-01-19 00:00:00  To:  2024-03-28 00:00:00
# Number of days {299}
# Log return distribution: p-value = 0.8386
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-01-19 00:00:00  To:  2024-05-03 00:00:00
# Number of days {324}
# Log return distribution: p-value = 0.6309
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-01-19 00:00:00  To:  2024-09-03 00:00:00
# Number of days {407}
# Log return distribution: p-value = 0.2077
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-03-28 00:00:00  To:  2024-07-12 00:00:00
# Number of days {324}
# Log return distribution: p-value = 0.6981
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-05-02 00:00:00  To:  2024-07-18 00:00:00
# Number of days {304}
# Log return distribution: p-value = 0.3189
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-05-02 00:00:00  To:  2023-10-20 00:00:00
# Number of days {119}
# Log return distribution: p-value = 0.2742
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-05-04 00:00:00  To:  2024-07-22 00:00:00
# Number of days {304}
# Log return distribution: p-value = 0.3238
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-06-27 00:00:00  To:  2024-02-09 00:00:00
# Number of days {157}
# Log return distribution: p-value = 0.3054
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-16 00:00:00  To:  2024-04-02 00:00:00
# Number of days {157}
# Log return distribution: p-value = 0.7520
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-09-13 00:00:00  To:  2024-04-29 00:00:00
# Number of days {157}
# Log return distribution: p-value = 0.7930
# → No statistically significant evidence against normality.

# %% [markdown]
# Below we show the largest time interval:

# %%
len_days_NASDAQ = normal_candidate_intervals_NASDAQ[:,1]- normal_candidate_intervals_NASDAQ[:,0]
normal_interval_large_NASDAQ = normal_candidate_intervals_NASDAQ[len_days_NASDAQ==np.max(len_days_NASDAQ),:]

# %%
m_ind_NASDAQ = np.shape(normal_interval_large_NASDAQ)[0]-1
historical_NASDAQ = log_daily_returns_NASDAQ_index_1[range(int(normal_interval_large_NASDAQ[m_ind_NASDAQ,0]), int(normal_interval_large_NASDAQ[m_ind_NASDAQ,1]) )]

p_value = stats.normaltest(historical_NASDAQ)[1]
    
fig,axes = plt.subplots(1,2, figsize=(16, 6))
stats.probplot(historical_NASDAQ, plot = axes[0])
axes[0].set_title("Portfolio Log Returns Probability Plot", fontsize=16)
axes[0].grid(True)

n = int(normal_interval_large_NASDAQ[m_ind_NASDAQ,1]) - int(normal_interval_large_NASDAQ[m_ind_NASDAQ,0])+1
NASDAQ_historical = NASDAQ_index['Close'].iloc[range(int(normal_interval_large_NASDAQ[m_ind_NASDAQ,0]), int(normal_interval_large_NASDAQ[m_ind_NASDAQ,1]) )]
plt.plot(NASDAQ_historical)
plt.title(f'Index ^IXIC log returns', size = 25)
plt.ylabel('Price (USD)')
plt.xticks(fontsize=10, rotation=90)

image_name = "source_reports/images/figure_3_project_2"
plt.savefig(image_name, format = image_format, dpi = image_save_dpi)

print('-----------------------')
print('From: ', log_daily_returns_NASDAQ_index.index.tolist()[int(normal_interval_large_NASDAQ[m_ind_NASDAQ,0]) ] , ' To: ', log_daily_returns_NASDAQ_index.index.tolist()[int(normal_interval_large_NASDAQ[m_ind_NASDAQ,1]) ])
print('Number of days', { n} )
print(f"^Portfolio log return distribution: p-value = {p_value:.4f}")
print("→ No statistically significant evidence against normality.")

normal_IXIC = pd.DataFrame(columns=['From', 'To', 'Number of days', 'p-value'], index = ["val"])
normal_IXIC.iloc[:,0]=log_daily_returns_NASDAQ_index.index.tolist()[int(normal_interval_large_NASDAQ[m_ind_NASDAQ,0]) ]
normal_IXIC.iloc[:,1]=log_daily_returns_NASDAQ_index.index.tolist()[int(normal_interval_large_NASDAQ[m_ind_NASDAQ,1]) ]
normal_IXIC.iloc[:,2]= n
normal_IXIC.iloc[:,3]= p_value
normal_IXIC.to_csv('source_reports/images/normal_IXIC.csv')
# Out:
# -----------------------
# From:  2021-11-22 00:00:00  To:  2023-08-25 00:00:00
# Number of days {442}
# ^Portfolio log return distribution: p-value = 0.1164
# → No statistically significant evidence against normality.

# %% [markdown]
# ## 3) Create a personalized portfolio of stocks with historical log return data that is normally distributed.

# %% [markdown]
# Portfolio composed of stocks from Alphabet, IBM, and Nvidia for a period of four years.

# %%
names_companies = ['Alphabet Inc.','International Business Machines Corporation','Nvidia' ]
tickers = ['GOOG', 'IBM', 'NVDA']
##
end_date = '2025-06-25'
start_date = pd.to_datetime(end_date) - dt.timedelta(days = 365*4)

stocks_personalized = yf.download(tickers, start = start_date, end=end_date)

log_daily_returns_personalized_individual = np.log(stocks_personalized['Close']/stocks_personalized['Close'].shift(1))
log_daily_returns_personalized_individual = log_daily_returns_personalized_individual.dropna()

log_daily_returns_personalized_pooled = log_daily_returns_personalized_individual.mean(axis=1)
log_daily_returns_personalized_pooled = np.array(log_daily_returns_personalized_pooled)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
start_date
# Out:
# Timestamp('2021-06-26 00:00:00')

# %%
min_len_pers =  int(np.floor(252/3)) # 4 months
ndays_pers = len(log_daily_returns_personalized_pooled)

size_interval_samples_pers = 50 
len_interval_samples_pers = np.sort(random.sample(range(min_len_pers, ndays_pers), size_interval_samples_pers) ) 

size_days_samples_pers = 50
days_samples_pers = np.sort(random.sample(range(0, ndays_pers), size_interval_samples_pers) )

# %%
normal_candidate_intervals_pers= normal_subintervals(log_daily_returns= log_daily_returns_personalized_pooled, 
                        days_samples=days_samples_pers,
                        size_days_samples=size_days_samples_pers, 
                        len_interval_samples =len_interval_samples_pers, 
                        size_interval_samples=size_interval_samples_pers, 
                        min_len=min_len_pers  )

# %% [markdown]
# Returning p-values for all the normal subintervals produced by the sample:

# %%
for j in range(np.shape(normal_candidate_intervals_pers)[0]):
    historical_pers = log_daily_returns_personalized_pooled[range(int(normal_candidate_intervals_pers[j,0]), int(normal_candidate_intervals_pers[j,1]) )]

    p_value_pers = stats.normaltest(historical_pers)[1]

    n = int(normal_candidate_intervals_pers[j,1]) - int(normal_candidate_intervals_pers[j,0])

    print('-----------------------')
    print('From: ', log_daily_returns_personalized_individual.index.tolist()[int(normal_candidate_intervals_pers[j,0]) ] , ' To: ', log_daily_returns_personalized_individual.index.tolist()[int(normal_candidate_intervals_pers[j,1]) ])
    print('Number of days', { n} )
    print(f"^Portfolio log return distribution: p-value = {p_value_pers:.4f}")
    print("→ No statistically significant evidence against normality.")
# Out:
# -----------------------
# From:  2021-07-02 00:00:00  To:  2023-05-09 00:00:00
# Number of days {465}
# ^Portfolio log return distribution: p-value = 0.0535
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-02 00:00:00  To:  2023-03-29 00:00:00
# Number of days {437}
# ^Portfolio log return distribution: p-value = 0.1080
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-02 00:00:00  To:  2022-12-22 00:00:00
# Number of days {372}
# ^Portfolio log return distribution: p-value = 0.0704
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-02 00:00:00  To:  2022-12-21 00:00:00
# Number of days {371}
# ^Portfolio log return distribution: p-value = 0.0689
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-02 00:00:00  To:  2022-12-19 00:00:00
# Number of days {369}
# ^Portfolio log return distribution: p-value = 0.0745
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-02 00:00:00  To:  2022-09-07 00:00:00
# Number of days {297}
# ^Portfolio log return distribution: p-value = 0.7384
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-12 00:00:00  To:  2022-12-29 00:00:00
# Number of days {371}
# ^Portfolio log return distribution: p-value = 0.1012
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-12 00:00:00  To:  2022-12-30 00:00:00
# Number of days {372}
# ^Portfolio log return distribution: p-value = 0.1131
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-12 00:00:00  To:  2022-09-14 00:00:00
# Number of days {297}
# ^Portfolio log return distribution: p-value = 0.4369
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-12 00:00:00  To:  2023-05-24 00:00:00
# Number of days {471}
# ^Portfolio log return distribution: p-value = 0.0653
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-12 00:00:00  To:  2023-05-16 00:00:00
# Number of days {465}
# ^Portfolio log return distribution: p-value = 0.0635
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-13 00:00:00  To:  2023-05-25 00:00:00
# Number of days {471}
# ^Portfolio log return distribution: p-value = 0.0641
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-13 00:00:00  To:  2022-09-27 00:00:00
# Number of days {305}
# ^Portfolio log return distribution: p-value = 0.4473
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-13 00:00:00  To:  2022-09-15 00:00:00
# Number of days {297}
# ^Portfolio log return distribution: p-value = 0.4374
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-14 00:00:00  To:  2021-12-06 00:00:00
# Number of days {101}
# ^Portfolio log return distribution: p-value = 0.3296
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-14 00:00:00  To:  2023-05-18 00:00:00
# Number of days {465}
# ^Portfolio log return distribution: p-value = 0.0738
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-14 00:00:00  To:  2023-01-03 00:00:00
# Number of days {371}
# ^Portfolio log return distribution: p-value = 0.1148
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-14 00:00:00  To:  2022-09-28 00:00:00
# Number of days {305}
# ^Portfolio log return distribution: p-value = 0.4403
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-14 00:00:00  To:  2022-09-16 00:00:00
# Number of days {297}
# ^Portfolio log return distribution: p-value = 0.4672
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-14 00:00:00  To:  2022-02-10 00:00:00
# Number of days {147}
# ^Portfolio log return distribution: p-value = 0.4503
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-19 00:00:00  To:  2022-08-02 00:00:00
# Number of days {262}
# ^Portfolio log return distribution: p-value = 0.9719
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-19 00:00:00  To:  2022-05-11 00:00:00
# Number of days {206}
# ^Portfolio log return distribution: p-value = 0.8470
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-19 00:00:00  To:  2023-05-23 00:00:00
# Number of days {465}
# ^Portfolio log return distribution: p-value = 0.0798
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-19 00:00:00  To:  2022-09-21 00:00:00
# Number of days {297}
# ^Portfolio log return distribution: p-value = 0.4167
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-22 00:00:00  To:  2023-04-18 00:00:00
# Number of days {437}
# ^Portfolio log return distribution: p-value = 0.1155
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-07-22 00:00:00  To:  2022-09-26 00:00:00
# Number of days {297}
# ^Portfolio log return distribution: p-value = 0.4764
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-08-18 00:00:00  To:  2022-01-11 00:00:00
# Number of days {101}
# ^Portfolio log return distribution: p-value = 0.5021
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-08-18 00:00:00  To:  2022-03-18 00:00:00
# Number of days {147}
# ^Portfolio log return distribution: p-value = 0.8657
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-08-18 00:00:00  To:  2022-05-09 00:00:00
# Number of days {182}
# ^Portfolio log return distribution: p-value = 0.9568
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-08-18 00:00:00  To:  2022-06-13 00:00:00
# Number of days {206}
# ^Portfolio log return distribution: p-value = 0.8563
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-08-18 00:00:00  To:  2022-08-12 00:00:00
# Number of days {248}
# ^Portfolio log return distribution: p-value = 0.8568
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-08-18 00:00:00  To:  2022-10-21 00:00:00
# Number of days {297}
# ^Portfolio log return distribution: p-value = 0.8653
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-08-18 00:00:00  To:  2022-08-22 00:00:00
# Number of days {254}
# ^Portfolio log return distribution: p-value = 0.8517
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-08-18 00:00:00  To:  2022-12-12 00:00:00
# Number of days {332}
# ^Portfolio log return distribution: p-value = 0.1935
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-08-18 00:00:00  To:  2022-12-19 00:00:00
# Number of days {337}
# ^Portfolio log return distribution: p-value = 0.2333
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-08-18 00:00:00  To:  2023-02-06 00:00:00
# Number of days {369}
# ^Portfolio log return distribution: p-value = 0.3476
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-08-18 00:00:00  To:  2023-02-08 00:00:00
# Number of days {371}
# ^Portfolio log return distribution: p-value = 0.3642
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-08-18 00:00:00  To:  2023-02-09 00:00:00
# Number of days {372}
# ^Portfolio log return distribution: p-value = 0.3674
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-08-18 00:00:00  To:  2023-05-15 00:00:00
# Number of days {437}
# ^Portfolio log return distribution: p-value = 0.1583
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-08-18 00:00:00  To:  2022-11-02 00:00:00
# Number of days {305}
# ^Portfolio log return distribution: p-value = 0.8911
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2022-10-12 00:00:00
# Number of days {254}
# ^Portfolio log return distribution: p-value = 0.9835
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2022-03-04 00:00:00
# Number of days {101}
# ^Portfolio log return distribution: p-value = 0.9789
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2022-05-10 00:00:00
# Number of days {147}
# ^Portfolio log return distribution: p-value = 0.6239
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2022-06-30 00:00:00
# Number of days {182}
# ^Portfolio log return distribution: p-value = 0.3263
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2022-08-04 00:00:00
# Number of days {206}
# ^Portfolio log return distribution: p-value = 0.5322
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2022-10-04 00:00:00
# Number of days {248}
# ^Portfolio log return distribution: p-value = 0.9806
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2022-12-02 00:00:00
# Number of days {290}
# ^Portfolio log return distribution: p-value = 0.3998
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2022-10-24 00:00:00
# Number of days {262}
# ^Portfolio log return distribution: p-value = 0.9312
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2022-12-23 00:00:00
# Number of days {305}
# ^Portfolio log return distribution: p-value = 0.3942
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2023-01-17 00:00:00
# Number of days {319}
# ^Portfolio log return distribution: p-value = 0.4658
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2023-02-03 00:00:00
# Number of days {332}
# ^Portfolio log return distribution: p-value = 0.5487
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2023-02-10 00:00:00
# Number of days {337}
# ^Portfolio log return distribution: p-value = 0.5263
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2023-03-29 00:00:00
# Number of days {369}
# ^Portfolio log return distribution: p-value = 0.4473
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2023-03-31 00:00:00
# Number of days {371}
# ^Portfolio log return distribution: p-value = 0.4406
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2023-04-03 00:00:00
# Number of days {372}
# ^Portfolio log return distribution: p-value = 0.4620
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-10-08 00:00:00  To:  2022-12-13 00:00:00
# Number of days {297}
# ^Portfolio log return distribution: p-value = 0.3505
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-12-06 00:00:00  To:  2022-12-20 00:00:00
# Number of days {262}
# ^Portfolio log return distribution: p-value = 0.4529
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-12-06 00:00:00  To:  2023-02-10 00:00:00
# Number of days {297}
# ^Portfolio log return distribution: p-value = 0.6091
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-12-06 00:00:00  To:  2023-02-01 00:00:00
# Number of days {290}
# ^Portfolio log return distribution: p-value = 0.5856
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-12-06 00:00:00  To:  2023-05-25 00:00:00
# Number of days {369}
# ^Portfolio log return distribution: p-value = 0.3724
# → No statistically significant evidence against normality.
# -----------------------
# From:  2021-12-06 00:00:00  To:  2023-02-23 00:00:00
# Number of days {305}
# ^Portfolio log return distribution: p-value = 0.5562
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-11 00:00:00  To:  2023-05-16 00:00:00
# Number of days {337}
# ^Portfolio log return distribution: p-value = 0.4391
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-11 00:00:00  To:  2023-05-09 00:00:00
# Number of days {332}
# ^Portfolio log return distribution: p-value = 0.4525
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-11 00:00:00  To:  2023-04-20 00:00:00
# Number of days {319}
# ^Portfolio log return distribution: p-value = 0.5245
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-11 00:00:00  To:  2023-03-30 00:00:00
# Number of days {305}
# ^Portfolio log return distribution: p-value = 0.6312
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-11 00:00:00  To:  2023-03-20 00:00:00
# Number of days {297}
# ^Portfolio log return distribution: p-value = 0.6332
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-11 00:00:00  To:  2023-03-09 00:00:00
# Number of days {290}
# ^Portfolio log return distribution: p-value = 0.6158
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-11 00:00:00  To:  2023-01-27 00:00:00
# Number of days {262}
# ^Portfolio log return distribution: p-value = 0.6389
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-11 00:00:00  To:  2023-01-17 00:00:00
# Number of days {254}
# ^Portfolio log return distribution: p-value = 0.6562
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-27 00:00:00  To:  2023-02-01 00:00:00
# Number of days {254}
# ^Portfolio log return distribution: p-value = 0.7958
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-27 00:00:00  To:  2023-04-04 00:00:00
# Number of days {297}
# ^Portfolio log return distribution: p-value = 0.7760
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-27 00:00:00  To:  2023-03-24 00:00:00
# Number of days {290}
# ^Portfolio log return distribution: p-value = 0.7892
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-27 00:00:00  To:  2023-05-05 00:00:00
# Number of days {319}
# ^Portfolio log return distribution: p-value = 0.5245
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-27 00:00:00  To:  2023-05-24 00:00:00
# Number of days {332}
# ^Portfolio log return distribution: p-value = 0.5381
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-27 00:00:00  To:  2023-04-17 00:00:00
# Number of days {305}
# ^Portfolio log return distribution: p-value = 0.6878
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-28 00:00:00  To:  2023-06-02 00:00:00
# Number of days {337}
# ^Portfolio log return distribution: p-value = 0.0539
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-28 00:00:00  To:  2023-05-25 00:00:00
# Number of days {332}
# ^Portfolio log return distribution: p-value = 0.5316
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-01-28 00:00:00  To:  2023-02-14 00:00:00
# Number of days {262}
# ^Portfolio log return distribution: p-value = 0.8138
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-02-02 00:00:00  To:  2023-05-11 00:00:00
# Number of days {319}
# ^Portfolio log return distribution: p-value = 0.4845
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-02-02 00:00:00  To:  2023-04-21 00:00:00
# Number of days {305}
# ^Portfolio log return distribution: p-value = 0.5435
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-02-02 00:00:00  To:  2023-04-11 00:00:00
# Number of days {297}
# ^Portfolio log return distribution: p-value = 0.6584
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-02-02 00:00:00  To:  2023-03-30 00:00:00
# Number of days {290}
# ^Portfolio log return distribution: p-value = 0.6868
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-02-02 00:00:00  To:  2023-02-17 00:00:00
# Number of days {262}
# ^Portfolio log return distribution: p-value = 0.7283
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-02-02 00:00:00  To:  2023-02-07 00:00:00
# Number of days {254}
# ^Portfolio log return distribution: p-value = 0.7453
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-02-02 00:00:00  To:  2023-01-30 00:00:00
# Number of days {248}
# ^Portfolio log return distribution: p-value = 0.7231
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-02-15 00:00:00  To:  2023-02-21 00:00:00
# Number of days {254}
# ^Portfolio log return distribution: p-value = 0.6701
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-02-15 00:00:00  To:  2023-03-03 00:00:00
# Number of days {262}
# ^Portfolio log return distribution: p-value = 0.6256
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-02-15 00:00:00  To:  2023-05-24 00:00:00
# Number of days {319}
# ^Portfolio log return distribution: p-value = 0.3981
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-02-15 00:00:00  To:  2023-04-24 00:00:00
# Number of days {297}
# ^Portfolio log return distribution: p-value = 0.4586
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-03-14 00:00:00  To:  2023-05-18 00:00:00
# Number of days {297}
# ^Portfolio log return distribution: p-value = 0.3275
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-03-14 00:00:00  To:  2023-05-09 00:00:00
# Number of days {290}
# ^Portfolio log return distribution: p-value = 0.3278
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-03-14 00:00:00  To:  2023-01-06 00:00:00
# Number of days {206}
# ^Portfolio log return distribution: p-value = 0.4693
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-06-21 00:00:00  To:  2023-03-13 00:00:00
# Number of days {182}
# ^Portfolio log return distribution: p-value = 0.0670
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-09-07 00:00:00  To:  2023-04-10 00:00:00
# Number of days {147}
# ^Portfolio log return distribution: p-value = 0.0711
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-09-19 00:00:00  To:  2023-02-13 00:00:00
# Number of days {101}
# ^Portfolio log return distribution: p-value = 0.0845
# → No statistically significant evidence against normality.
# -----------------------
# From:  2022-11-30 00:00:00  To:  2023-04-27 00:00:00
# Number of days {101}
# ^Portfolio log return distribution: p-value = 0.4568
# → No statistically significant evidence against normality.
# -----------------------
# From:  2024-02-23 00:00:00  To:  2024-07-19 00:00:00
# Number of days {101}
# ^Portfolio log return distribution: p-value = 0.2043
# → No statistically significant evidence against normality.
# -----------------------
# From:  2024-07-03 00:00:00  To:  2024-11-25 00:00:00
# Number of days {101}
# ^Portfolio log return distribution: p-value = 0.0535
# → No statistically significant evidence against normality.
# -----------------------
# From:  2024-08-08 00:00:00  To:  2025-01-02 00:00:00
# Number of days {101}
# ^Portfolio log return distribution: p-value = 0.0638
# → No statistically significant evidence against normality.
# -----------------------
# From:  2024-08-16 00:00:00  To:  2025-01-13 00:00:00
# Number of days {101}
# ^Portfolio log return distribution: p-value = 0.0703
# → No statistically significant evidence against normality.

# %% [markdown]
# As before, we select the longest time interval:

# %%
len_days_pers = normal_candidate_intervals_pers[:,1]- normal_candidate_intervals_pers[:,0]
normal_interval_large_pers = normal_candidate_intervals_pers[len_days_pers==np.max(len_days_pers),:]

# %%
image_name = "source_reports/images/figure_4_project_2"

m_ind_pers = np.shape(normal_interval_large_pers)[0]-1
historical_pers = log_daily_returns_personalized_pooled[range(int(normal_interval_large_pers[m_ind_pers,0]), int(normal_interval_large_pers[m_ind_pers,1]) )]

p_value_pers = stats.normaltest(historical_pers)[1]
    
fig,axes = plt.subplots(1,2, figsize=(16, 6))
stats.probplot(historical_pers, plot = axes[0])
axes[0].set_title("Portfolio Log Returns Probability Plot", fontsize=16)
axes[0].grid(True)

n = int(normal_interval_large_pers[m_ind_pers,1]) - int(normal_interval_large_pers[m_ind_pers,0])+1
plt.plot(historical_pers)
plt.title(f'Portfolio stocks log returns', size = 25)
plt.ylabel('')
plt.xticks(fontsize=10, rotation=90)

plt.savefig(image_name, format = image_format, dpi = image_save_dpi)

print('-----------------------')
print('From: ', log_daily_returns_personalized_individual.index.tolist()[int(normal_interval_large_pers[m_ind_pers,0]) ] , ' To: ', log_daily_returns_personalized_individual.index.tolist()[int(normal_interval_large_pers[m_ind_pers,1]) ])
print('Number of days', { n} )
print(f"^Portfolio log return distribution: p-value = {p_value_pers:.4f}")
print("→ No statistically significant evidence against normality.")

normal_porforlio = pd.DataFrame(columns=['From', 'To', 'Number of days', 'p-value'], index = ["val"])
normal_porforlio.iloc[:,0]=log_daily_returns_personalized_individual.index.tolist()[int(normal_interval_large_pers[m_ind_pers,0]) ]
normal_porforlio.iloc[:,1]=log_daily_returns_personalized_individual.index.tolist()[int(normal_interval_large_pers[m_ind_pers,1]) ]
normal_porforlio.iloc[:,2]= n
normal_porforlio.iloc[:,3]= p_value_pers
normal_porforlio.to_csv('source_reports/images/normal_portfolio.csv')
# Out:
# -----------------------
# From:  2021-07-13 00:00:00  To:  2023-05-25 00:00:00
# Number of days {472}
# ^Portfolio log return distribution: p-value = 0.0641
# → No statistically significant evidence against normality.

# %% [markdown]
# ## 4) Test if the portfolio you created in the first mini-project has significant periods of time with evidence of normally distributed log returns.

# %%
names_companies = ['Fast Retailing Co., Ltd.','Alphabet Inc.','International Business Machines Corporation','JPMorgan Chase & Co.','Netflix, Inc.','Exxon Mobil Corporation','Yum! Brands, Inc.' ]
tickers = ['FRCOY', 'GOOG', 'IBM', 'JPM', 'NFLX', 'XOM', 'YUM']

##
end_date = '2025-06-25'
start_date = pd.to_datetime(end_date) - dt.timedelta(days = 365*2)

###
#start_date = dt.datetime.today()-dt.timedelta(days = 2*365)
#end_date = dt.datetime.today()
#end_date = '2025-06-25'
stock = yf.download(tickers, start = start_date, end=end_date)

log_daily_returns_proj_1_individual = np.log(stock['Close']/stock['Close'].shift(1))
log_daily_returns_proj_1_individual = log_daily_returns_proj_1_individual.dropna()

log_daily_returns_proj_1_pooled = log_daily_returns_proj_1_individual.mean(axis=1)
log_daily_returns_proj_1_pooled = np.array(log_daily_returns_proj_1_pooled)
# Out:
# [*********************100%***********************]  7 of 7 completed

# %%
p_historical_proj_1 = stats.normaltest(log_daily_returns_proj_1_pooled)[1]

print(f"Portfolio Project 1 log return distribution: p-value = {p_historical_proj_1:.4f}")
if p_historical_proj_1 < 0.05:
    print("→ Statistically significant evidence that the data is NOT normally distributed.")
else:
    print("→ No statistically significant evidence against normality.")

plt.figure(figsize=(8,5))
stats.probplot(log_daily_returns_proj_1_pooled, plot = plt)
plt.title("Portfolio Log Returns Probability Plot", fontsize=16)
plt.savefig("Figure2_p2.png")

plt.show()
plt.figure(figsize=(12,4))
plt.plot(log_daily_returns_proj_1_pooled)
plt.title(f'Portfolio stocks log returns', size = 25)
plt.ylabel('')
plt.savefig("Figure3_p2.png")

plt.show()
# Out:
# Portfolio Project 1 log return distribution: p-value = 0.0000
# → Statistically significant evidence that the data is NOT normally distributed.

# %%
p_historical_proj_1
# Out:
# 2.970977697213335e-22

# %% [markdown]
# According to the test, the porfolio for the miniproject is not normally distributed for the two years period. Now we will proceed to find periods in which this portfolio shows normality.

# %%
min_len =  int(np.floor(252/3)) # 4 months
ndays = len(log_daily_returns_proj_1_pooled)

size_interval_samples = 50 
len_interval_samples = np.sort(random.sample(range(min_len, ndays), size_interval_samples) ) 

size_days_samples = 50
days_samples = np.sort(random.sample(range(0, ndays), size_days_samples) )

# %%
normal_candidate_intervals= normal_subintervals(log_daily_returns= log_daily_returns_proj_1_pooled, 
                        days_samples=days_samples,
                        size_days_samples=size_days_samples, 
                        len_interval_samples =len_interval_samples, 
                        size_interval_samples=size_interval_samples, 
                        min_len=min_len  )

# %%
for j in range(np.shape(normal_candidate_intervals)[0]):
    historical_pooled = log_daily_returns_proj_1_pooled[range(int(normal_candidate_intervals[j,0]), int(normal_candidate_intervals[j,1]) )]

    p_value = stats.normaltest(historical_pooled)[1]

    n = int(normal_candidate_intervals[j,1]) - int(normal_candidate_intervals[j,0])

    print('-----------------------')
    print('From: ', log_daily_returns_proj_1_individual.index.tolist()[int(normal_candidate_intervals[j,0]) ] , ' To: ', log_daily_returns_proj_1_individual.index.tolist()[int(normal_candidate_intervals[j,1]) ])
    print('Number of days', { n} )
    print(f"^Portfolio log return distribution: p-value = {p_value:.4f}")
    print("→ No statistically significant evidence against normality.")
# Out:
# -----------------------
# From:  2023-08-01 00:00:00  To:  2024-07-02 00:00:00
# Number of days {231}
# ^Portfolio log return distribution: p-value = 0.0733
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-01 00:00:00  To:  2024-06-18 00:00:00
# Number of days {222}
# ^Portfolio log return distribution: p-value = 0.1381
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-01 00:00:00  To:  2024-05-24 00:00:00
# Number of days {206}
# ^Portfolio log return distribution: p-value = 0.1640
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-01 00:00:00  To:  2024-05-23 00:00:00
# Number of days {205}
# ^Portfolio log return distribution: p-value = 0.1372
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-01 00:00:00  To:  2024-04-11 00:00:00
# Number of days {175}
# ^Portfolio log return distribution: p-value = 0.5290
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-01 00:00:00  To:  2024-04-01 00:00:00
# Number of days {167}
# ^Portfolio log return distribution: p-value = 0.5498
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-01 00:00:00  To:  2024-02-21 00:00:00
# Number of days {140}
# ^Portfolio log return distribution: p-value = 0.7242
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-02 00:00:00  To:  2023-12-28 00:00:00
# Number of days {103}
# ^Portfolio log return distribution: p-value = 0.7513
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-02 00:00:00  To:  2024-02-22 00:00:00
# Number of days {140}
# ^Portfolio log return distribution: p-value = 0.6934
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-02 00:00:00  To:  2024-02-29 00:00:00
# Number of days {145}
# ^Portfolio log return distribution: p-value = 0.6947
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-02 00:00:00  To:  2024-06-20 00:00:00
# Number of days {222}
# ^Portfolio log return distribution: p-value = 0.1138
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-02 00:00:00  To:  2024-07-03 00:00:00
# Number of days {231}
# ^Portfolio log return distribution: p-value = 0.0705
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-02 00:00:00  To:  2024-05-24 00:00:00
# Number of days {205}
# ^Portfolio log return distribution: p-value = 0.1463
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-25 00:00:00  To:  2024-04-09 00:00:00
# Number of days {155}
# ^Portfolio log return distribution: p-value = 0.3532
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-25 00:00:00  To:  2024-03-18 00:00:00
# Number of days {140}
# ^Portfolio log return distribution: p-value = 0.4304
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-25 00:00:00  To:  2024-03-25 00:00:00
# Number of days {145}
# ^Portfolio log return distribution: p-value = 0.3971
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-25 00:00:00  To:  2024-04-19 00:00:00
# Number of days {163}
# ^Portfolio log return distribution: p-value = 0.0626
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-25 00:00:00  To:  2024-04-11 00:00:00
# Number of days {157}
# ^Portfolio log return distribution: p-value = 0.3399
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-25 00:00:00  To:  2024-05-07 00:00:00
# Number of days {175}
# ^Portfolio log return distribution: p-value = 0.1173
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-25 00:00:00  To:  2024-06-20 00:00:00
# Number of days {205}
# ^Portfolio log return distribution: p-value = 0.0634
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-25 00:00:00  To:  2024-06-21 00:00:00
# Number of days {206}
# ^Portfolio log return distribution: p-value = 0.0574
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-25 00:00:00  To:  2024-07-29 00:00:00
# Number of days {231}
# ^Portfolio log return distribution: p-value = 0.0530
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-08-25 00:00:00  To:  2024-04-25 00:00:00
# Number of days {167}
# ^Portfolio log return distribution: p-value = 0.0883
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-09-20 00:00:00  To:  2024-02-12 00:00:00
# Number of days {99}
# ^Portfolio log return distribution: p-value = 0.4274
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-09-20 00:00:00  To:  2024-02-16 00:00:00
# Number of days {103}
# ^Portfolio log return distribution: p-value = 0.6146
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-09-20 00:00:00  To:  2024-04-11 00:00:00
# Number of days {140}
# ^Portfolio log return distribution: p-value = 0.4018
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-09-20 00:00:00  To:  2024-05-02 00:00:00
# Number of days {155}
# ^Portfolio log return distribution: p-value = 0.1823
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-09-20 00:00:00  To:  2024-04-18 00:00:00
# Number of days {145}
# ^Portfolio log return distribution: p-value = 0.0979
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-09-20 00:00:00  To:  2024-05-14 00:00:00
# Number of days {163}
# ^Portfolio log return distribution: p-value = 0.1293
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-09-20 00:00:00  To:  2024-05-20 00:00:00
# Number of days {167}
# ^Portfolio log return distribution: p-value = 0.0896
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-09-20 00:00:00  To:  2024-05-31 00:00:00
# Number of days {175}
# ^Portfolio log return distribution: p-value = 0.1384
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-09-20 00:00:00  To:  2024-05-06 00:00:00
# Number of days {157}
# ^Portfolio log return distribution: p-value = 0.1628
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-03-04 00:00:00
# Number of days {99}
# ^Portfolio log return distribution: p-value = 0.5681
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-02-15 00:00:00
# Number of days {88}
# ^Portfolio log return distribution: p-value = 0.4595
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-02-16 00:00:00
# Number of days {89}
# ^Portfolio log return distribution: p-value = 0.5455
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-02-21 00:00:00
# Number of days {91}
# ^Portfolio log return distribution: p-value = 0.5361
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-02-22 00:00:00
# Number of days {92}
# ^Portfolio log return distribution: p-value = 0.5041
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-02-29 00:00:00
# Number of days {97}
# ^Portfolio log return distribution: p-value = 0.5132
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-03-01 00:00:00
# Number of days {98}
# ^Portfolio log return distribution: p-value = 0.5302
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-03-08 00:00:00
# Number of days {103}
# ^Portfolio log return distribution: p-value = 0.5093
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-06-21 00:00:00
# Number of days {175}
# ^Portfolio log return distribution: p-value = 0.0622
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-05-01 00:00:00
# Number of days {140}
# ^Portfolio log return distribution: p-value = 0.1061
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-05-22 00:00:00
# Number of days {155}
# ^Portfolio log return distribution: p-value = 0.0529
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-05-24 00:00:00
# Number of days {157}
# ^Portfolio log return distribution: p-value = 0.0870
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-06-04 00:00:00
# Number of days {163}
# ^Portfolio log return distribution: p-value = 0.1017
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-06-10 00:00:00
# Number of days {167}
# ^Portfolio log return distribution: p-value = 0.0814
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-04-22 00:00:00
# Number of days {133}
# ^Portfolio log return distribution: p-value = 0.0822
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-10 00:00:00  To:  2024-08-05 00:00:00
# Number of days {205}
# ^Portfolio log return distribution: p-value = 0.0706
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-17 00:00:00  To:  2024-06-17 00:00:00
# Number of days {167}
# ^Portfolio log return distribution: p-value = 0.0951
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-17 00:00:00  To:  2024-06-11 00:00:00
# Number of days {163}
# ^Portfolio log return distribution: p-value = 0.0877
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-17 00:00:00  To:  2024-03-11 00:00:00
# Number of days {99}
# ^Portfolio log return distribution: p-value = 0.5772
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-10-17 00:00:00  To:  2024-02-23 00:00:00
# Number of days {88}
# ^Portfolio log return distribution: p-value = 0.6925
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-11-14 00:00:00  To:  2024-03-27 00:00:00
# Number of days {91}
# ^Portfolio log return distribution: p-value = 0.1037
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-11-14 00:00:00  To:  2024-04-09 00:00:00
# Number of days {99}
# ^Portfolio log return distribution: p-value = 0.1392
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-11-15 00:00:00  To:  2024-04-10 00:00:00
# Number of days {99}
# ^Portfolio log return distribution: p-value = 0.0955
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-11-21 00:00:00  To:  2024-04-12 00:00:00
# Number of days {97}
# ^Portfolio log return distribution: p-value = 0.0862
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-11-29 00:00:00  To:  2024-04-29 00:00:00
# Number of days {103}
# ^Portfolio log return distribution: p-value = 0.0564
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-11-29 00:00:00  To:  2024-04-12 00:00:00
# Number of days {92}
# ^Portfolio log return distribution: p-value = 0.1312
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-11-29 00:00:00  To:  2024-04-11 00:00:00
# Number of days {91}
# ^Portfolio log return distribution: p-value = 0.1348
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-11-30 00:00:00  To:  2024-04-12 00:00:00
# Number of days {91}
# ^Portfolio log return distribution: p-value = 0.1353
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-12-13 00:00:00  To:  2024-05-13 00:00:00
# Number of days {103}
# ^Portfolio log return distribution: p-value = 0.0663
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-12-20 00:00:00  To:  2024-05-14 00:00:00
# Number of days {99}
# ^Portfolio log return distribution: p-value = 0.0770
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-12-20 00:00:00  To:  2024-05-02 00:00:00
# Number of days {91}
# ^Portfolio log return distribution: p-value = 0.1286
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-12-28 00:00:00  To:  2024-05-28 00:00:00
# Number of days {103}
# ^Portfolio log return distribution: p-value = 0.0890
# → No statistically significant evidence against normality.
# -----------------------
# From:  2023-12-28 00:00:00  To:  2024-05-10 00:00:00
# Number of days {92}
# ^Portfolio log return distribution: p-value = 0.1149
# → No statistically significant evidence against normality.
# -----------------------
# From:  2024-01-17 00:00:00  To:  2024-06-13 00:00:00
# Number of days {103}
# ^Portfolio log return distribution: p-value = 0.0782
# → No statistically significant evidence against normality.
# -----------------------
# From:  2024-06-27 00:00:00  To:  2024-11-06 00:00:00
# Number of days {92}
# ^Portfolio log return distribution: p-value = 0.0709
# → No statistically significant evidence against normality.

# %%
len_days = normal_candidate_intervals[:,1]- normal_candidate_intervals[:,0]
normal_interval_large = normal_candidate_intervals[len_days==np.max(len_days),:]

# %%
m_ind = np.shape(normal_interval_large)[0]-1
historical_pooled = log_daily_returns_proj_1_pooled[range(int(normal_interval_large[m_ind,0]), int(normal_interval_large[m_ind,1]) )]

p_value = stats.normaltest(historical_pooled)[1]
    
fig,axes = plt.subplots(1,2, figsize=(16, 6))
stats.probplot(historical_pooled, plot = axes[0])
axes[0].set_title("Portfolio Log Returns Probability Plot", fontsize=16)
axes[0].grid(True)

n = int(normal_interval_large[m_ind,1]) - int(normal_interval_large[m_ind,0])+1
plt.plot(historical_pooled)
plt.title(f'Portfolio stocks log returns', size = 25)
plt.ylabel('')
plt.xticks(fontsize=10, rotation=90)
plt.savefig("Figure4_p2.png")

plt.show()
print('-----------------------')
print('From: ', log_daily_returns_proj_1_individual.index.tolist()[int(normal_interval_large[m_ind,0]) ] , ' To: ', log_daily_returns_proj_1_individual.index.tolist()[int(normal_interval_large[m_ind,1]) ])
print('Number of days', { n} )
print(f"^Portfolio log return distribution: p-value = {p_value:.4f}")
print("→ No statistically significant evidence against normality.")
# Out:
# -----------------------
# From:  2023-08-25 00:00:00  To:  2024-07-29 00:00:00
# Number of days {232}
# ^Portfolio log return distribution: p-value = 0.0530
# → No statistically significant evidence against normality.

# %% [markdown]
# ## 5) Gather x-number of historical stock data and just perform a normality test on their log return data to see if any of the stocks exhibit evidence of log returns that are normally distributed.

# %% [markdown]
# For examining the historical stock data, we have taken the list of companies that belong to the SP500 index during a five years time period. We removed the companies for which data was not available for the whole time period. By simplicity, we run the algorithm and extract for each company the longest time interval normally distributed.

# %%
sp500 = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

symbols_list = sorted(sp500['Symbol'].unique().tolist())

ind = [i for i in range(0, len(symbols_list)) if symbols_list[i] == "BRK.B" or symbols_list[i] == "BF.B"] #removing companies for which data is not available
symbols_list = [i for j, i in enumerate(symbols_list) if j not in ind]

end_date = '2025-06-25'
start_date = pd.to_datetime(end_date) - dt.timedelta(days = 365*5)

index_sp500 = yf.download(tickers = symbols_list, start = start_date, end = end_date)
# Out:
# [*********************100%***********************]  501 of 501 completed

# %%
cc = np.zeros(len(symbols_list),dtype =int)-1
for i in range(len(symbols_list)):
    if (index_sp500.iloc[:,i].isnull()).sum()== 0:
        cc[i] = i
cc = cc[cc>-1]
        
index_sp500_remove_na = index_sp500.iloc[:,cc]
symbols_listb = np.array(symbols_list)
symbols_listb = symbols_listb[cc].tolist()

log_daily_returns_sp500_individual = np.log(index_sp500_remove_na['Close']/index_sp500_remove_na['Close'].shift(1))
log_daily_returns_sp500_individual = log_daily_returns_sp500_individual.dropna()
log_daily_returns_sp500_ind = np.array(log_daily_returns_sp500_individual)

# %%
summary_SP = np.zeros(( np.shape(index_sp500_remove_na)[1], 4))

for ind in range(np.shape(index_sp500_remove_na)[1]):
    min_len_sp_ind =  int(np.floor(252/3)) # 4 months
    ndays_sp500 = len(log_daily_returns_sp500_ind[:,ind])

    size_interval_samples_sp = 10
    len_interval_samples_sp = np.sort(random.sample(range(min_len_sp_ind, ndays_sp500), size_interval_samples_sp)) 

    size_days_samples_sp = 10
    days_samples_sp = np.sort(random.sample(range(0, ndays_sp500), size_days_samples_sp))  
    #print(ind, "=ind")
    normal_candidate_intervals_SP_ind = normal_subintervals(log_daily_returns= log_daily_returns_sp500_ind[:,ind], 
                            days_samples=days_samples_sp,
                            size_days_samples=size_days_samples_sp, 
                            len_interval_samples =len_interval_samples_sp, 
                            size_interval_samples=size_interval_samples_sp, 
                            min_len=min_len_sp_ind)
    
    if np.sum(normal_candidate_intervals_SP_ind)==0:
        #print('No intervals sampled')
        summary_SP[ind,0] = -1
        summary_SP[ind,1] = -1
        summary_SP[ind,2] = -1
    else:
        len_days_SP = normal_candidate_intervals_SP_ind[:,1]- normal_candidate_intervals_SP_ind[:,0]
        normal_interval_large_SP = normal_candidate_intervals_SP_ind[len_days_SP == np.max(len_days_SP),:]
        m_ind_SP = np.shape(normal_interval_large_SP)[0]-1

        h_SP = log_daily_returns_sp500_ind[:,ind][range(int(normal_candidate_intervals_SP_ind[m_ind_SP,0]), int(normal_candidate_intervals_SP_ind[m_ind_SP,1]) )]
        p_val = stats.normaltest(h_SP)[1]

        summary_SP[ind,0] = int(normal_candidate_intervals_SP_ind[m_ind_SP,0])
        summary_SP[ind,1] = int(normal_candidate_intervals_SP_ind[m_ind_SP,1])
        summary_SP[ind,2] = p_val

# %%
summary_SP_data = pd.DataFrame(summary_SP)
for i in range(np.shape(summary_SP)[0]):
    if summary_SP_data.iloc[i,0] > -1:
        summary_SP_data.iloc[i,0] = log_daily_returns_sp500_individual.index.tolist()[int(summary_SP[i,0])  ]
        summary_SP_data.iloc[i,1] = log_daily_returns_sp500_individual.index.tolist()[int(summary_SP[i,1])  ]
        summary_SP_data.iloc[i,2] = summary_SP[i,2]
        summary_SP_data.iloc[i,3] = symbols_listb[i]

summary_SP_data.columns = ['From', 'To', 'p-value', 'Company']

summary_SP_data = summary_SP_data[(summary_SP_data.iloc[:,2]>-1)]
# Out:
# /tmp/ipykernel_591829/1052410174.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2022-03-07 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   summary_SP_data.iloc[i,0] = log_daily_returns_sp500_individual.index.tolist()[int(summary_SP[i,0])  ]
# /tmp/ipykernel_591829/1052410174.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2022-10-24 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   summary_SP_data.iloc[i,1] = log_daily_returns_sp500_individual.index.tolist()[int(summary_SP[i,1])  ]
# /tmp/ipykernel_591829/1052410174.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   summary_SP_data.iloc[i,3] = symbols_listb[i]

# %% [markdown]
# The companies' time intervals that exhibit normality are shown below. Note that some companies were excluded, this is because no viable interval was proposed when sampling. Accurancy will improve when increasing the number of intervals proposed.

# %%
summary_SP_data
# Out:
#                     From                   To   p-value Company
# 0    2022-03-07 00:00:00  2022-10-24 00:00:00  0.741447       A
# 1    2021-04-23 00:00:00  2021-12-14 00:00:00  0.390048    AAPL
# 2    2024-05-01 00:00:00  2024-10-15 00:00:00  0.418872    ABBV
# 3    2021-09-16 00:00:00  2022-09-28 00:00:00  0.552368     ABT
# 4    2021-02-05 00:00:00  2022-06-30 00:00:00  0.090476    ACGL
# ..                   ...                  ...       ...     ...
# 482  2021-04-23 00:00:00  2022-03-08 00:00:00  0.534896     XEL
# 483  2023-08-28 00:00:00  2025-01-23 00:00:00  0.505859     XOM
# 484  2022-05-12 00:00:00  2022-10-28 00:00:00  0.718833     XYL
# 485  2020-07-22 00:00:00  2021-12-21 00:00:00  0.083536     XYZ
# 486  2021-12-29 00:00:00  2022-10-21 00:00:00  0.670210     YUM
#
# [275 rows x 4 columns]

# %%
summary_SP_data.to_csv('source_reports/images/normal_summary_SP_data.csv')
